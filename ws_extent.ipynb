# %%
import geopandas as gpd
import os
os.getcwd()
# Out:
# 'C:\\Users\\taohuang\\Downloads\\goat_creek-main(1)\\goat_creek-main'

# %%
shapefile = gpd.read_file("goat_creek/layers/globalwatershed.shp")
print(shapefile)
# Out:
#                      Name                                           geometry
# 0  ID20230417204331377000  POLYGON ((-115.01217 44.13835, -115.01229 44.1...

# %%
shapefile.boundary
# Out:
# 0    LINESTRING (-115.01217 44.13835, -115.01229 44...
# dtype: geometry

# %%
shapefile.boundary[0]
